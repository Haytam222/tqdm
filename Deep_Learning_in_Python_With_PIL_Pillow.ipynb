# %% [markdown]
# <a href="https://colab.research.google.com/github/Haytam222/tqdm/blob/master/Deep_Learning_in_Python_With_PIL_Pillow.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ***Deep Learning in Python With PIL/Pillow***

# %%
#How to Install Pillow
# !sudo pip install Pillow

# %%
# check Pillow version number
import PIL
print('Pillow Version:', PIL.__version__)
# Out:
# Pillow Version: 7.0.0

# %%
# load and show an image with Pillow
from PIL import Image
# load the image
image = Image.open('Image/dog.jpg')
# summarize some details about the image
print(image.format)
print(image.mode)
print(image.size)
# show the image
image.show()
# Out:
# JPEG
# RGB
# (1920, 1871)

# %%
# load and display an image with Matplotlib
from matplotlib import image
from matplotlib import pyplot
# load image as pixel array
data = image.imread('Image/dog.jpg')
# summarize shape of the pixel array
print(data.dtype)
print(data.shape)
# display the array of pixels as an image
pyplot.imshow(data)
pyplot.show()
# Out:
# uint8
# (1871, 1920, 3)

# %%
# load image and convert to and from NumPy array
from PIL import Image
from numpy import asarray
# load the image
image = Image.open('Image/dog.jpg')
# convert image to numpy array
data = asarray(image)
# summarize shape
print(data.shape)
# create Pillow image
image2 = Image.fromarray(data)
# summarize image details
print(image2.format)
print(image2.mode)
print(image2.size)
# Out:
# (1871, 1920, 3)
# None
# RGB
# (1920, 1871)

# %%
# load and display an image with Matplotlib
from matplotlib import image
from matplotlib import pyplot
# load image as pixel array
data = image.imread('Image/dog.jpg')
# summarize shape of the pixel array
print(data.dtype)
print(data.shape)
# display the array of pixels as an image
pyplot.imshow(data)
pyplot.show()
print(data)
# Out:
# uint8
# (1871, 1920, 3)
# [[[103 143  72]
#   [102 144  72]
#   [102 144  72]
#   ...
#   [ 82 129  77]
#   [ 81 129  79]
#   [ 81 129  79]]
#
#  [[103 145  73]
#   [102 144  72]
#   [102 144  72]
#   ...
#   [ 82 129  77]
#   [ 81 129  79]
#   [ 81 129  79]]
#
#  [[102 145  73]
#   [102 145  73]
#   [102 145  74]
#   ...
#   [ 82 129  77]
#   [ 81 129  79]
#   [ 82 130  80]]
#
#  ...
#
#  [[ 91 140  61]
#   [ 87 138  61]
#   [ 83 134  59]
#   ...
#   [123 140  86]
#   [119 144  87]
#   [114 145  86]]
#
#  [[ 86 129  50]
#   [ 86 130  55]
#   [ 84 131  59]
#   ...
#   [123 137  86]
#   [118 141  87]
#   [118 145  90]]
#
#  [[ 84 121  41]
#   [ 81 119  44]
#   [ 83 125  59]
#   ...
#   [124 137  81]
#   [121 141  82]
#   [123 147  87]]]
